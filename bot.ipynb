# %%
# !pip install fastf1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fastf1
#   Downloading fastf1-3.3.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 KB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting scipy<2.0.0,>=1.7.3
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 23.1 MB/s eta 0:00:0000:0100:01
# Collecting requests>=2.28.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 KB 19.4 MB/s eta 0:00:00
# Collecting matplotlib<4.0.0,>=3.5.1
#   Downloading matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 65.6 MB/s eta 0:00:0000:010:01
# Collecting websockets>=10.3
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 49.0 MB/s eta 0:00:00
# Collecting numpy<2.0.0,>=1.21.5
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 49.2 MB/s eta 0:00:0000:0100:01
# Collecting thefuzz
#   Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Collecting requests-cache>=1.0.0
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 KB 30.2 MB/s eta 0:00:00
# Collecting pandas<3.0.0,>=1.4.1
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 68.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from fastf1) (2.9.0.post0)
# Collecting timple>=0.1.6
#   Downloading timple-0.1.8-py3-none-any.whl (17 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 69.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (23.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 96.6 MB/s eta 0:00:00ta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 156.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 89.4 MB/s eta 0:00:00ta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 94.4 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 91.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->fastf1) (1.16.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 39.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 KB 30.5 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 KB 28.7 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 50.2 MB/s eta 0:00:00
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting cattrs>=22.2
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests-cache>=1.0.0->fastf1) (4.2.0)
# Collecting attrs>=21.2
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 KB 27.8 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.0.0
#   Downloading rapidfuzz-3.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: exceptiongroup>=1.1.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (1.2.0)
# Collecting typing-extensions!=4.6.3,>=4.1.0
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Installing collected packages: pytz, websockets, urllib3, url-normalize, tzdata, typing-extensions, rapidfuzz, pillow, numpy, kiwisolver, idna, fonttools, cycler, charset-normalizer, certifi, attrs, thefuzz, scipy, requests, pandas, contourpy, cattrs, requests-cache, matplotlib, timple, fastf1
# Successfully installed attrs-23.2.0 cattrs-23.2.3 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.0 cycler-0.12.1 fastf1-3.3.0 fonttools-4.49.0 idna-3.6 kiwisolver-1.4.5 matplotlib-3.8.3 numpy-1.26.4 pandas-2.2.1 pillow-10.2.0 pytz-2024.1 rapidfuzz-3.6.2 requests-2.31.0 requests-cache-1.2.0 scipy-1.12.0 thefuzz-0.22.1 timple-0.1.8 typing-extensions-4.10.0 tzdata-2024.1 url-normalize-1.4.3 urllib3-2.2.1 websockets-12.0

# %%
import fastf1
import os
import json
import utils

YEAR = 2020

events = [
'70th Anniversary Grand Prix',
'Abu Dhabi Grand Prix',
'Austrian Grand Prix', 
'Bahrain Grand Prix',
'Belgian Grand Prix', 
'British Grand Prix', 
'Eifel Grand Prix', 
'Emilia Romagna Grand Prix',
'Hungarian Grand Prix',
'Italian Grand Prix',
'Portuguese Grand Prix', 
'Russian Grand Prix',
'Spanish Grand Prix', 
'Styrian Grand Prix', 
    'Turkish Grand Prix', 
    
     
    
     'Tuscan Grand Prix', 
    
    
     
    
    
     'Sakhir Grand Prix',
    

]
# sessions = [
#     "Practice 1",
#       "Practice 2",
#       "Practice 3",
#       # "Qualifying",
#       # "Race",
# ]

def sessions_available(year: int, event: str | int) -> any:
    # get sessions available for a given year and event
    event = str(event)
    data = utils.LatestData(year)
    sessions = data.get_sessions(event)
    return sessions

for event in events:
    sessions = utils.get_sessions(YEAR, event)
    for session in sessions:
        f1session = fastf1.get_session(YEAR, event, session)
        f1session.load(laps=True, telemetry=False, weather=False, messages=False)
        circuit_info = f1session.get_circuit_info().corners
        corner_info ={
            "CornerNumber": circuit_info['Number'].tolist(),
            "X": circuit_info['X'].tolist(),
            "Y": circuit_info['Y'].tolist(),
            "Angle": circuit_info['Angle'].tolist(),
            "Distance": circuit_info['Distance'].tolist(),
        }

        driver_folder = f"{event}/{session}"
        file_path = f"{event}/{session}/corners.json"
        if not os.path.exists(driver_folder):
            os.makedirs(driver_folder)
        # Save the dictionary to a JSON file
        with open(file_path, "w") as json_file:
            json.dump(corner_info, json_file)
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 23: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  5: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 99: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Austrian Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Austrian Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.3.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 77: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 16: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  4: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 44: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 55: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 11: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 10: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 31: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 99: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  5: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 26: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 23: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 20: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver 18: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Driver  3: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Styrian Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Styrian Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Styrian Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 14; current 15)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1591: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:00:39.414000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '55', '77', '31', '4', '23', '10', '3', '5', '16', '63', '18', '26', '20', '7', '11', '6', '99', '8']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Styrian Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Skipping lap alignment (no suitable lap)!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '4', '11', '18', '3', '55', '26', '7', '20', '8', '99', '10', '63', '6', '31', '16', '5']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 10
# core        WARNING 	No lap data for driver 7
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 10)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 7)
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 6; current 7)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1591: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:38:40.318000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1591: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:02:48.965000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1591: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 00:57:10.594000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1591: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<TimedeltaArray>
# ['0 days 01:20:35.093000']
# Length: 1, dtype: timedelta64[ns]' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   result.loc[mask, 'LapStartTime'] = result.loc[mask, 'PitOutTime']
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '23', '5', '11', '3', '55', '20', '16', '26', '4', '31', '7', '8', '99', '63', '6', '10']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 0
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 65535
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 0)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 11)
# core        WARNING 	Driver 23: Lap timing integrity check failed for 1 lap(s)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 65535)
# core        WARNING 	Driver 99: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 23 drivers: ['0', '10', '11', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '65535', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for British Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for British Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for British Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver  4: Ignoring late data for a previously processed lap.The data may contain errors (previous: 35; current 36)
# _api        WARNING 	Driver  8: Encountered 1 timing integrity error(s) near lap(s): [15].
# This might be a bug and should be reported.
# _api        WARNING 	Skipping lap alignment (no suitable lap)!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '3', '4', '31', '10', '23', '18', '5', '77', '63', '55', '99', '6', '8', '7', '26', '20', '27']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 10: Ignoring late data for a previously processed lap.The data may contain errors (previous: 16; current 17)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# core           INFO 	Finished loading data for 21 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  6: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '27', '33', '3', '18', '10', '16', '23', '4', '31', '5', '55', '8', '63', '26', '20', '6', '99', '7']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '23', '18', '27', '31', '4', '26', '10', '5', '55', '3', '7', '8', '99', '63', '6', '20']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Spanish Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Spanish Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver  7: Ignoring late data for a previously processed lap.The data may contain errors (previous: 9; current 10)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Spanish Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '18', '23', '55', '4', '16', '10', '5', '26', '3', '7', '31', '20', '8', '63', '6', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '11', '55', '5', '23', '10', '4', '3', '26', '31', '7', '20', '99', '63', '6', '8', '16']
# ...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  6: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver  6: Ignoring late data for a previously processed lap.The data may contain errors (previous: 18; current 19)
# _api        WARNING 	Driver 10: Ignoring late data for a previously processed lap.The data may contain errors (previous: 29; current 30)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	No lap data for driver 7
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 7)
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 3 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 6; current 7)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '11', '3', '31', '10', '4', '26', '5', '16', '18', '63', '55', '99', '7', '20', '8', '6']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 55: Encountered 1 timing integrity error(s) near lap(s): [48].
# This might be a bug and should be reported.
# _api        WARNING 	Skipping lap alignment (no suitable lap)!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# data        WARNING 	Failed to generate marker distance information: telemetry data has not been loaded
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 1 [v3.3.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 18; current 19)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 89: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspace/2020/bot.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> f1session = fastf1.get_session(YEAR, event, session)
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> f1session.load(laps=True, telemetry=False, weather=False, messages=False)
# ---> <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a> circuit_info = f1session.get_circuit_info().corners
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a> corner_info ={
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a>     "CornerNumber": circuit_info['Number'].tolist(),
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a>     "X": circuit_info['X'].tolist(),
#    (...)
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a>     "Distance": circuit_info['Distance'].tolist(),
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a> }
#      <a href='vscode-notebook-cell://tracinginsightsa-2020-tg9i2wcyg87.ws-us108.gitpod.io/workspace/2020/bot.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a> driver_folder = f"{event}/{session}"
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:2442, in Session.get_circuit_info(self)
#    2431 """Returns additional information about the circuit that hosts this
#    2432 event.
#    2433
#    (...)
#    2439 See :class:`~fastf1.mvapi.CircuitInfo` for detailed information.
#    2440 """
#    2441 circuit_key = self.session_info['Meeting']['Circuit']['Key']
# -> 2442 circuit_info = get_circuit_info(year=self.event.year,
#    2443                                 circuit_key=circuit_key)
#    2444 circuit_info.add_marker_distance(
#    2445     reference_lap=self.laps.pick_fastest()
#    2446 )
#    2447 return circuit_info
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/mvapi/data.py:138, in get_circuit_info(year, circuit_key)
#     136 for cat in ('corners', 'marshalLights', 'marshalSectors'):
#     137     rows = list()
# --> 138     for entry in data[cat]:
#     139         rows.append((
#     140             float(entry.get('trackPosition', {}).get('x', 0.0)),
#     141             float(entry.get('trackPosition', {}).get('y', 0.0)),
#    (...)
#     145             np.nan
#     146         ))
#     147     ret.append(
#     148         pd.DataFrame(
#     149             rows,
#     150             columns=['X', 'Y', 'Number', 'Letter', 'Angle', 'Distance']
#     151         )
#     152     )
#
# TypeError: 'NoneType' object is not iterable

# %%
# !pip install fastapi requests pandas lxml fastf1 -q

# %%
YEAR = 2020

# %%
import fastf1
fastf1.Cache.enable_cache("cache")

# %%
import utils
import fastf1
def events_available(year: int) -> any:
    # get events available for a given year
    data = utils.LatestData(year)
    events = data.get_events()
    return events

events = events_available(YEAR)
print(events)
# Out:
# ['Austrian Grand Prix', 'Styrian Grand Prix', 'Hungarian Grand Prix', 'British Grand Prix', '70th Anniversary Grand Prix', 'Spanish Grand Prix', 'Belgian Grand Prix', 'Italian Grand Prix', 'Tuscan Grand Prix', 'Russian Grand Prix', 'Eifel Grand Prix', 'Portuguese Grand Prix', 'Emilia Romagna Grand Prix', 'Turkish Grand Prix', 'Bahrain Grand Prix', 'Sakhir Grand Prix', 'Abu Dhabi Grand Prix']

# %%
def sessions_available(year: int, event: str | int) -> any:
    # get sessions available for a given year and event
    event = str(event)
    data = utils.LatestData(year)
    sessions = data.get_sessions(event)
    return sessions

# %%
import os

# Your list of events
events_list = events

# Create a folder for each event in the current working directory
for event in events_list:
    event_directory = os.path.join(os.getcwd(), event)

    # Check if the folder already exists before creating it
    if not os.path.exists(event_directory):
        os.makedirs(event_directory)
        print(f"Folder created for {event}: {event_directory}")
    else:
        print(f"Folder already exists for {event}: {event_directory}")
# Out:
# Folder already exists for Austrian Grand Prix: /workspaces/2020/Austrian Grand Prix
# Folder already exists for Styrian Grand Prix: /workspaces/2020/Styrian Grand Prix
# Folder already exists for Hungarian Grand Prix: /workspaces/2020/Hungarian Grand Prix
# Folder already exists for British Grand Prix: /workspaces/2020/British Grand Prix
# Folder already exists for 70th Anniversary Grand Prix: /workspaces/2020/70th Anniversary Grand Prix
# Folder already exists for Spanish Grand Prix: /workspaces/2020/Spanish Grand Prix
# Folder already exists for Belgian Grand Prix: /workspaces/2020/Belgian Grand Prix
# Folder already exists for Italian Grand Prix: /workspaces/2020/Italian Grand Prix
# Folder already exists for Tuscan Grand Prix: /workspaces/2020/Tuscan Grand Prix
# Folder already exists for Russian Grand Prix: /workspaces/2020/Russian Grand Prix
# Folder already exists for Eifel Grand Prix: /workspaces/2020/Eifel Grand Prix
# Folder already exists for Portuguese Grand Prix: /workspaces/2020/Portuguese Grand Prix
# Folder already exists for Emilia Romagna Grand Prix: /workspaces/2020/Emilia Romagna Grand Prix
# Folder already exists for Turkish Grand Prix: /workspaces/2020/Turkish Grand Prix
# Folder already exists for Bahrain Grand Prix: /workspaces/2020/Bahrain Grand Prix
# Folder already exists for Sakhir Grand Prix: /workspaces/2020/Sakhir Grand Prix
# Folder already exists for Abu Dhabi Grand Prix: /workspaces/2020/Abu Dhabi Grand Prix

# %%
def session_drivers(year: int, event: str | int, session: str) -> any:
    # get drivers available for a given year, event and session
    import fastf1
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=True, weather=False, messages=False)

    laps = f1session.laps
    team_colors = utils.team_colors(year)
    # add team_colors dict to laps on Team column
    laps["color"] = laps["Team"].map(team_colors)

    unique_drivers = laps["Driver"].unique()

    drivers = [
        {

            "driver": driver,
            "team": laps[laps.Driver == driver].Team.iloc[0],
        }
        for driver in unique_drivers
    ]

    return  {"drivers": drivers}

# %%
import os

# Your list of events
events_list = events

# Loop through each event
for event in events_list:
    event_directory = os.path.join(os.getcwd(), event)

    # Check if the event folder already exists before creating it
    if not os.path.exists(event_directory):
        os.makedirs(event_directory)
        print(f"Folder created for {event}: {event_directory}")
    else:
        print(f"Folder already exists for {event}: {event_directory}")

    # Get sessions for the current event
    sessions = sessions_available(YEAR, event)

    # Loop through each session and create a folder within the event folder
    for session in sessions:
        session_directory = os.path.join(event_directory, session)

        # Check if the session folder already exists before creating it
        if not os.path.exists(session_directory):
            os.makedirs(session_directory)
            print(f"Folder created for {event} - {session}: {session_directory}")
        else:
            print(f"Folder already exists for {event} - {session}: {session_directory}")
# Out:
# Folder already exists for Austrian Grand Prix: /workspaces/2020/Austrian Grand Prix
# Folder already exists for Austrian Grand Prix - Practice 1: /workspaces/2020/Austrian Grand Prix/Practice 1
# Folder already exists for Austrian Grand Prix - Practice 2: /workspaces/2020/Austrian Grand Prix/Practice 2
# Folder already exists for Austrian Grand Prix - Practice 3: /workspaces/2020/Austrian Grand Prix/Practice 3
# Folder already exists for Austrian Grand Prix - Qualifying: /workspaces/2020/Austrian Grand Prix/Qualifying
# Folder already exists for Austrian Grand Prix - Race: /workspaces/2020/Austrian Grand Prix/Race
# Folder already exists for Styrian Grand Prix: /workspaces/2020/Styrian Grand Prix
# Folder already exists for Styrian Grand Prix - Practice 1: /workspaces/2020/Styrian Grand Prix/Practice 1
# Folder already exists for Styrian Grand Prix - Practice 2: /workspaces/2020/Styrian Grand Prix/Practice 2
# Folder already exists for Styrian Grand Prix - Practice 3: /workspaces/2020/Styrian Grand Prix/Practice 3
# Folder already exists for Styrian Grand Prix - Qualifying: /workspaces/2020/Styrian Grand Prix/Qualifying
# Folder already exists for Styrian Grand Prix - Race: /workspaces/2020/Styrian Grand Prix/Race
# Folder already exists for Hungarian Grand Prix: /workspaces/2020/Hungarian Grand Prix
# Folder already exists for Hungarian Grand Prix - Practice 1: /workspaces/2020/Hungarian Grand Prix/Practice 1
# Folder already exists for Hungarian Grand Prix - Practice 2: /workspaces/2020/Hungarian Grand Prix/Practice 2
# Folder already exists for Hungarian Grand Prix - Practice 3: /workspaces/2020/Hungarian Grand Prix/Practice 3
# Folder already exists for Hungarian Grand Prix - Qualifying: /workspaces/2020/Hungarian Grand Prix/Qualifying
# Folder already exists for Hungarian Grand Prix - Race: /workspaces/2020/Hungarian Grand Prix/Race
# Folder already exists for British Grand Prix: /workspaces/2020/British Grand Prix
# Folder already exists for British Grand Prix - Practice 1: /workspaces/2020/British Grand Prix/Practice 1
# Folder already exists for British Grand Prix - Practice 2: /workspaces/2020/British Grand Prix/Practice 2
# Folder already exists for British Grand Prix - Practice 3: /workspaces/2020/British Grand Prix/Practice 3
# Folder already exists for British Grand Prix - Qualifying: /workspaces/2020/British Grand Prix/Qualifying
# Folder already exists for British Grand Prix - Race: /workspaces/2020/British Grand Prix/Race
# Folder already exists for 70th Anniversary Grand Prix: /workspaces/2020/70th Anniversary Grand Prix
# Folder already exists for 70th Anniversary Grand Prix - Practice 1: /workspaces/2020/70th Anniversary Grand Prix/Practice 1
# Folder already exists for 70th Anniversary Grand Prix - Practice 2: /workspaces/2020/70th Anniversary Grand Prix/Practice 2
# Folder already exists for 70th Anniversary Grand Prix - Practice 3: /workspaces/2020/70th Anniversary Grand Prix/Practice 3
# Folder already exists for 70th Anniversary Grand Prix - Qualifying: /workspaces/2020/70th Anniversary Grand Prix/Qualifying
# Folder already exists for 70th Anniversary Grand Prix - Race: /workspaces/2020/70th Anniversary Grand Prix/Race
# Folder already exists for Spanish Grand Prix: /workspaces/2020/Spanish Grand Prix
# Folder already exists for Spanish Grand Prix - Practice 1: /workspaces/2020/Spanish Grand Prix/Practice 1
# Folder already exists for Spanish Grand Prix - Practice 2: /workspaces/2020/Spanish Grand Prix/Practice 2
# Folder already exists for Spanish Grand Prix - Practice 3: /workspaces/2020/Spanish Grand Prix/Practice 3
# Folder already exists for Spanish Grand Prix - Qualifying: /workspaces/2020/Spanish Grand Prix/Qualifying
# Folder already exists for Spanish Grand Prix - Race: /workspaces/2020/Spanish Grand Prix/Race
# Folder already exists for Belgian Grand Prix: /workspaces/2020/Belgian Grand Prix
# Folder already exists for Belgian Grand Prix - Practice 1: /workspaces/2020/Belgian Grand Prix/Practice 1
# Folder already exists for Belgian Grand Prix - Practice 2: /workspaces/2020/Belgian Grand Prix/Practice 2
# Folder already exists for Belgian Grand Prix - Practice 3: /workspaces/2020/Belgian Grand Prix/Practice 3
# Folder already exists for Belgian Grand Prix - Qualifying: /workspaces/2020/Belgian Grand Prix/Qualifying
# Folder already exists for Belgian Grand Prix - Race: /workspaces/2020/Belgian Grand Prix/Race
# Folder already exists for Italian Grand Prix: /workspaces/2020/Italian Grand Prix
# Folder already exists for Italian Grand Prix - Practice 1: /workspaces/2020/Italian Grand Prix/Practice 1
# Folder already exists for Italian Grand Prix - Practice 2: /workspaces/2020/Italian Grand Prix/Practice 2
# Folder already exists for Italian Grand Prix - Practice 3: /workspaces/2020/Italian Grand Prix/Practice 3
# Folder already exists for Italian Grand Prix - Qualifying: /workspaces/2020/Italian Grand Prix/Qualifying
# Folder already exists for Italian Grand Prix - Race: /workspaces/2020/Italian Grand Prix/Race
# Folder already exists for Tuscan Grand Prix: /workspaces/2020/Tuscan Grand Prix
# Folder already exists for Tuscan Grand Prix - Practice 1: /workspaces/2020/Tuscan Grand Prix/Practice 1
# Folder already exists for Tuscan Grand Prix - Practice 2: /workspaces/2020/Tuscan Grand Prix/Practice 2
# Folder already exists for Tuscan Grand Prix - Practice 3: /workspaces/2020/Tuscan Grand Prix/Practice 3
# Folder already exists for Tuscan Grand Prix - Qualifying: /workspaces/2020/Tuscan Grand Prix/Qualifying
# Folder already exists for Tuscan Grand Prix - Race: /workspaces/2020/Tuscan Grand Prix/Race
# Folder already exists for Russian Grand Prix: /workspaces/2020/Russian Grand Prix
# Folder already exists for Russian Grand Prix - Practice 1: /workspaces/2020/Russian Grand Prix/Practice 1
# Folder already exists for Russian Grand Prix - Practice 2: /workspaces/2020/Russian Grand Prix/Practice 2
# Folder already exists for Russian Grand Prix - Practice 3: /workspaces/2020/Russian Grand Prix/Practice 3
# Folder already exists for Russian Grand Prix - Qualifying: /workspaces/2020/Russian Grand Prix/Qualifying
# Folder already exists for Russian Grand Prix - Race: /workspaces/2020/Russian Grand Prix/Race
# Folder already exists for Eifel Grand Prix: /workspaces/2020/Eifel Grand Prix
# Folder already exists for Eifel Grand Prix - Practice 1: /workspaces/2020/Eifel Grand Prix/Practice 1
# Folder already exists for Eifel Grand Prix - Practice 2: /workspaces/2020/Eifel Grand Prix/Practice 2
# Folder already exists for Eifel Grand Prix - Practice 3: /workspaces/2020/Eifel Grand Prix/Practice 3
# Folder already exists for Eifel Grand Prix - Qualifying: /workspaces/2020/Eifel Grand Prix/Qualifying
# Folder already exists for Eifel Grand Prix - Race: /workspaces/2020/Eifel Grand Prix/Race
# Folder already exists for Portuguese Grand Prix: /workspaces/2020/Portuguese Grand Prix
# Folder already exists for Portuguese Grand Prix - Practice 1: /workspaces/2020/Portuguese Grand Prix/Practice 1
# Folder already exists for Portuguese Grand Prix - Practice 2: /workspaces/2020/Portuguese Grand Prix/Practice 2
# Folder already exists for Portuguese Grand Prix - Practice 3: /workspaces/2020/Portuguese Grand Prix/Practice 3
# Folder already exists for Portuguese Grand Prix - Qualifying: /workspaces/2020/Portuguese Grand Prix/Qualifying
# Folder already exists for Portuguese Grand Prix - Race: /workspaces/2020/Portuguese Grand Prix/Race
# Folder already exists for Emilia Romagna Grand Prix: /workspaces/2020/Emilia Romagna Grand Prix
# Folder already exists for Emilia Romagna Grand Prix - Practice: /workspaces/2020/Emilia Romagna Grand Prix/Practice
# Folder already exists for Emilia Romagna Grand Prix - Qualifying: /workspaces/2020/Emilia Romagna Grand Prix/Qualifying
# Folder already exists for Emilia Romagna Grand Prix - Race: /workspaces/2020/Emilia Romagna Grand Prix/Race
# Folder already exists for Turkish Grand Prix: /workspaces/2020/Turkish Grand Prix
# Folder already exists for Turkish Grand Prix - Practice 1: /workspaces/2020/Turkish Grand Prix/Practice 1
# Folder already exists for Turkish Grand Prix - Practice 2: /workspaces/2020/Turkish Grand Prix/Practice 2
# Folder already exists for Turkish Grand Prix - Practice 3: /workspaces/2020/Turkish Grand Prix/Practice 3
# Folder already exists for Turkish Grand Prix - Qualifying: /workspaces/2020/Turkish Grand Prix/Qualifying
# Folder already exists for Turkish Grand Prix - Race: /workspaces/2020/Turkish Grand Prix/Race
# Folder already exists for Bahrain Grand Prix: /workspaces/2020/Bahrain Grand Prix
# Folder already exists for Bahrain Grand Prix - Practice 1: /workspaces/2020/Bahrain Grand Prix/Practice 1
# Folder already exists for Bahrain Grand Prix - Practice 2: /workspaces/2020/Bahrain Grand Prix/Practice 2
# Folder already exists for Bahrain Grand Prix - Practice 3: /workspaces/2020/Bahrain Grand Prix/Practice 3
# Folder already exists for Bahrain Grand Prix - Qualifying: /workspaces/2020/Bahrain Grand Prix/Qualifying
# Folder already exists for Bahrain Grand Prix - Race: /workspaces/2020/Bahrain Grand Prix/Race
# Folder already exists for Sakhir Grand Prix: /workspaces/2020/Sakhir Grand Prix
# Folder already exists for Sakhir Grand Prix - Practice 1: /workspaces/2020/Sakhir Grand Prix/Practice 1
# Folder already exists for Sakhir Grand Prix - Practice 2: /workspaces/2020/Sakhir Grand Prix/Practice 2
# Folder already exists for Sakhir Grand Prix - Practice 3: /workspaces/2020/Sakhir Grand Prix/Practice 3
# Folder already exists for Sakhir Grand Prix - Qualifying: /workspaces/2020/Sakhir Grand Prix/Qualifying
# Folder already exists for Sakhir Grand Prix - Race: /workspaces/2020/Sakhir Grand Prix/Race
# Folder already exists for Abu Dhabi Grand Prix: /workspaces/2020/Abu Dhabi Grand Prix
# Folder already exists for Abu Dhabi Grand Prix - Practice 1: /workspaces/2020/Abu Dhabi Grand Prix/Practice 1
# Folder already exists for Abu Dhabi Grand Prix - Practice 2: /workspaces/2020/Abu Dhabi Grand Prix/Practice 2
# Folder already exists for Abu Dhabi Grand Prix - Practice 3: /workspaces/2020/Abu Dhabi Grand Prix/Practice 3
# Folder already exists for Abu Dhabi Grand Prix - Qualifying: /workspaces/2020/Abu Dhabi Grand Prix/Qualifying
# Folder already exists for Abu Dhabi Grand Prix - Race: /workspaces/2020/Abu Dhabi Grand Prix/Race

# %%
events =[ 'Turkish Grand Prix', 'Bahrain Grand Prix', 'Sakhir Grand Prix', 'Abu Dhabi Grand Prix']

# %%
import os

# Your list of events
events_list = events

# Loop through each event
for event in events_list:
    if event == "Styrian Grand Prix":
        sessions = ["Practice 1", "Practice 2", "Qualifying", "Race"]
    if event == "Eifel Grand Prix":
         sessions = ["Practice 3", "Qualifying", "Race"]
    if event == "Emilia Romagna Grand Prix":
        sessions = ["Practice 1", "Qualifying", "Race"]

    else:
        # Get sessions for the current event
        sessions = sessions_available(YEAR, event)

    # Loop through each session and create a folder within the event folder
    for session in sessions:


        drivers = session_drivers(YEAR, event, session)

        import json

        # Specify the file path where you want to save the JSON data
        file_path = f"{event}/{session}/drivers.json"

        # Save the dictionary to a JSON file
        with open(file_path, "w") as json_file:
            json.dump(drivers, json_file)

        print(f"Dictionary saved to {file_path}")
# Out:
# core           INFO 	Loading data for Turkish Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Turkish Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Dictionary saved to Turkish Grand Prix/Practice 1/drivers.json
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Turkish Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Dictionary saved to Turkish Grand Prix/Practice 2/drivers.json
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Turkish Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Dictionary saved to Turkish Grand Prix/Practice 3/drivers.json
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['18', '33', '11', '23', '3', '44', '31', '7', '77', '99', '4', '5', '55', '16', '10', '20', '26', '63', '8', '6']
# core           INFO 	Loading data for Turkish Grand Prix - Race [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Turkish Grand Prix/Qualifying/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['44', '11', '5', '16', '55', '33', '23', '4', '18', '3', '31', '26', '10', '77', '7', '63', '20', '8', '6', '99']
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Turkish Grand Prix/Race/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver  6: Ignoring late data for a previously processed lap.The data may contain errors (previous: 18; current 19)
# _api        WARNING 	Driver 10: Ignoring late data for a previously processed lap.The data may contain errors (previous: 29; current 30)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	No lap data for driver 7
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 7)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Bahrain Grand Prix/Practice 1/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver  1: Car data is incomplete!
# _api        WARNING 	Driver  2: Car data is incomplete!
# _api        WARNING 	Driver  9: Car data is incomplete!
# _api        WARNING 	Driver 12: Car data is incomplete!
# _api        WARNING 	Driver 14: Car data is incomplete!
# _api        WARNING 	Driver 15: Car data is incomplete!
# _api        WARNING 	Driver 17: Car data is incomplete!
# _api        WARNING 	Driver 19: Car data is incomplete!
# _api        WARNING 	Driver 21: Car data is incomplete!
# _api        WARNING 	Driver 22: Car data is incomplete!
# _api        WARNING 	Driver 24: Car data is incomplete!
# _api        WARNING 	Driver 25: Car data is incomplete!
# _api        WARNING 	Driver 27: Car data is incomplete!
# _api        WARNING 	Driver 28: Car data is incomplete!
# _api        WARNING 	Driver 29: Car data is incomplete!
# _api        WARNING 	Driver 30: Car data is incomplete!
# _api        WARNING 	Driver 33: Car data is incomplete!
# _api        WARNING 	Driver 44: Car data is incomplete!
# _api        WARNING 	Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 63: Car data is incomplete!
# _api        WARNING 	Driver 77: Car data is incomplete!
# _api        WARNING 	Driver 99: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 30: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# _api        WARNING 	Driver  1: Position data is incomplete!
# _api        WARNING 	Driver  2: Position data is incomplete!
# _api        WARNING 	Driver  9: Position data is incomplete!
# _api        WARNING 	Driver 12: Position data is incomplete!
# _api        WARNING 	Driver 14: Position data is incomplete!
# _api        WARNING 	Driver 15: Position data is incomplete!
# _api        WARNING 	Driver 17: Position data is incomplete!
# _api        WARNING 	Driver 19: Position data is incomplete!
# _api        WARNING 	Driver 21: Position data is incomplete!
# _api        WARNING 	Driver 22: Position data is incomplete!
# _api        WARNING 	Driver 24: Position data is incomplete!
# _api        WARNING 	Driver 25: Position data is incomplete!
# _api        WARNING 	Driver 27: Position data is incomplete!
# _api        WARNING 	Driver 28: Position data is incomplete!
# _api        WARNING 	Driver 29: Position data is incomplete!
# _api        WARNING 	Driver 33: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 99: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Bahrain Grand Prix/Practice 2/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Bahrain Grand Prix/Practice 3/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 6; current 7)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '11', '3', '31', '10', '4', '26', '5', '16', '18', '63', '55', '99', '7', '20', '8', '6']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Bahrain Grand Prix/Qualifying/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 55: Encountered 1 timing integrity error(s) near lap(s): [48].
# This might be a bug and should be reported.
# _api        WARNING 	Skipping lap alignment (no suitable lap)!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Bahrain Grand Prix/Race/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 18; current 19)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver  1: Car data is incomplete!
# _api        WARNING 	Driver  2: Car data is incomplete!
# _api        WARNING 	Driver  8: Car data is incomplete!
# _api        WARNING 	Driver  9: Car data is incomplete!
# _api        WARNING 	Driver 12: Car data is incomplete!
# _api        WARNING 	Driver 14: Car data is incomplete!
# _api        WARNING 	Driver 15: Car data is incomplete!
# _api        WARNING 	Driver 17: Car data is incomplete!
# _api        WARNING 	Driver 19: Car data is incomplete!
# _api        WARNING 	Driver 21: Car data is incomplete!
# _api        WARNING 	Driver 22: Car data is incomplete!
# _api        WARNING 	Driver 24: Car data is incomplete!
# _api        WARNING 	Driver 25: Car data is incomplete!
# _api        WARNING 	Driver 27: Car data is incomplete!
# _api        WARNING 	Driver 28: Car data is incomplete!
# _api        WARNING 	Driver 29: Car data is incomplete!
# _api        WARNING 	Driver 30: Car data is incomplete!
# _api        WARNING 	Driver 33: Car data is incomplete!
# _api        WARNING 	Driver 51: Car data is incomplete!
# _api        WARNING 	Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 63: Car data is incomplete!
# _api        WARNING 	Driver 77: Car data is incomplete!
# _api        WARNING 	Driver 89: Car data is incomplete!
# _api        WARNING 	Driver 99: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Sakhir Grand Prix/Practice 1/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 11: Ignoring late data for a previously processed lap.The data may contain errors (previous: 51; current 52)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Sakhir Grand Prix/Practice 2/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 5; current 6)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Qualifying [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Sakhir Grand Prix/Practice 3/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver  1: Car data is incomplete!
# _api        WARNING 	Driver  2: Car data is incomplete!
# _api        WARNING 	Driver  8: Car data is incomplete!
# _api        WARNING 	Driver  9: Car data is incomplete!
# _api        WARNING 	Driver 12: Car data is incomplete!
# _api        WARNING 	Driver 14: Car data is incomplete!
# _api        WARNING 	Driver 15: Car data is incomplete!
# _api        WARNING 	Driver 17: Car data is incomplete!
# _api        WARNING 	Driver 19: Car data is incomplete!
# _api        WARNING 	Driver 21: Car data is incomplete!
# _api        WARNING 	Driver 27: Car data is incomplete!
# _api        WARNING 	Driver 41: Car data is incomplete!
# _api        WARNING 	Driver 43: Car data is incomplete!
# _api        WARNING 	Driver 44: Car data is incomplete!
# _api        WARNING 	Driver 46: Car data is incomplete!
# _api        WARNING 	Driver 47: Car data is incomplete!
# _api        WARNING 	Driver 49: Car data is incomplete!
# _api        WARNING 	Driver 66: Car data is incomplete!
# _api        WARNING 	Driver 75: Car data is incomplete!
# _api        WARNING 	Driver 76: Car data is incomplete!
# _api        WARNING 	Driver 23: Car data is incomplete!
# _api        WARNING 	Driver 26: Car data is incomplete!
# _api        WARNING 	Driver 31: Car data is incomplete!
# _api        WARNING 	Driver 33: Car data is incomplete!
# _api        WARNING 	Driver 51: Car data is incomplete!
# _api        WARNING 	Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 63: Car data is incomplete!
# _api        WARNING 	Driver 77: Car data is incomplete!
# _api        WARNING 	Driver 89: Car data is incomplete!
# _api        WARNING 	Driver 99: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver  1: Position data is incomplete!
# _api        WARNING 	Driver  2: Position data is incomplete!
# _api        WARNING 	Driver  8: Position data is incomplete!
# _api        WARNING 	Driver  9: Position data is incomplete!
# _api        WARNING 	Driver 12: Position data is incomplete!
# _api        WARNING 	Driver 14: Position data is incomplete!
# _api        WARNING 	Driver 15: Position data is incomplete!
# _api        WARNING 	Driver 17: Position data is incomplete!
# _api        WARNING 	Driver 19: Position data is incomplete!
# _api        WARNING 	Driver 21: Position data is incomplete!
# _api        WARNING 	Driver 27: Position data is incomplete!
# _api        WARNING 	Driver 41: Position data is incomplete!
# _api        WARNING 	Driver 43: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 46: Position data is incomplete!
# _api        WARNING 	Driver 47: Position data is incomplete!
# _api        WARNING 	Driver 49: Position data is incomplete!
# _api        WARNING 	Driver 66: Position data is incomplete!
# _api        WARNING 	Driver 75: Position data is incomplete!
# _api        WARNING 	Driver 76: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 78: Position data is incomplete!
# _api        WARNING 	Driver 79: Position data is incomplete!
# _api        WARNING 	Driver 87: Position data is incomplete!
# _api        WARNING 	Driver 91: Position data is incomplete!
# _api        WARNING 	Driver 92: Position data is incomplete!
# _api        WARNING 	Driver 99: Position data is incomplete!
# _api        WARNING 	Driver 23: Position data is incomplete!
# _api        WARNING 	Driver 26: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 33: Position data is incomplete!
# _api        WARNING 	Driver 51: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 89: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['77', '63', '33', '16', '11', '26', '3', '55', '10', '18', '31', '23', '5', '99', '4', '20', '6', '89', '7', '51']
# core           INFO 	Loading data for Sakhir Grand Prix - Race [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Sakhir Grand Prix/Qualifying/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['11', '31', '18', '55', '3', '23', '26', '77', '63', '4', '10', '5', '99', '7', '20', '89', '51', '6', '33', '16']
# Dictionary saved to Sakhir Grand Prix/Race/drivers.json
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	Using cached data for season_schedule
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 18: Encountered 1 timing integrity error(s) near lap(s): [24].
# This might be a bug and should be reported.
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 20
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 20)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '50', '51', '55', '6', '63', '7', '77', '88', '99']
# Dictionary saved to Abu Dhabi Grand Prix/Practice 1/drivers.json
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Abu Dhabi Grand Prix/Practice 2/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Abu Dhabi Grand Prix/Practice 3/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# Dictionary saved to Abu Dhabi Grand Prix/Qualifying/drivers.json
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']
# Dictionary saved to Abu Dhabi Grand Prix/Race/drivers.json

# %%
def session_drivers_list(year: int, event: str | int, session: str) -> any:
    # get drivers available for a given year, event and session
    import fastf1
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=True, weather=False, messages=False)

    laps = f1session.laps


    unique_drivers = laps["Driver"].unique()


    return  list(unique_drivers)

# %%
session_drivers_list(2018,"Bahrain Grand Prix", "Race")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.1.6]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Skipping lap alignment (no suitable lap)!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# core        WARNING 	Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# core        WARNING 	Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# logger      WARNING 	Failed to load telemetry data!
# core           INFO 	Finished loading data for 20 drivers: ['5', '77', '44', '10', '20', '27', '14', '2', '9', '31', '55', '16', '8', '18', '35', '11', '28', '7', '33', '3']
# ['GAS',
#  'PER',
#  'ALO',
#  'LEC',
#  'STR',
#  'VAN',
#  'MAG',
#  'HUL',
#  'HAR',
#  'RIC',
#  'OCO',
#  'VER',
#  'SIR',
#  'HAM',
#  'VET',
#  'SAI',
#  'RAI',
#  'BOT',
#  'GRO',
#  'ERI']

# %%
def laps_data(year: int, event: str | int, session: str, driver: str) -> any:
    # get drivers available for a given year, event, and session
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps

    # add team_colors dict to laps on Team column

    # for each driver in drivers, get the Team column from laps and get the color from team_colors dict
    drivers_data = []

    driver_laps = laps.pick_driver(driver)
    driver_laps["LapTime"] = driver_laps["LapTime"].dt.total_seconds()
    # remove rows where LapTime is null
    driver_laps = driver_laps[driver_laps.LapTime.notnull()]

    drivers_data = {
        "time": driver_laps["LapTime"].tolist(),
        "lap": driver_laps["LapNumber"].tolist(),
        "compound": driver_laps["Compound"].tolist(),
    }



    return drivers_data


# # Example usage:
# result = laps_data(2018, "Bahrain", "R", "GAS")
# result

# %%
# # reversing a pyton list
# events.reverse()

# %%
import os
import json

# Your list of events
events_list = events

# Loop through each event
for event in events_list:
    sessions = sessions_available(YEAR, event)
    if event == "Styrian Grand Prix":
        sessions = ["Practice 1", "Practice 2", "Qualifying", "Race"]
    if event == "Eifel Grand Prix":
        sessions = ["Practice 3", "Qualifying", "Race"]
    if event == "Emilia Romagna Grand Prix":
        sessions = ["Practice 1", "Qualifying", "Race"]




    # Loop through each session and create a folder within the event folder
    for session in sessions:
        drivers = session_drivers(YEAR, event, session)

        for driver in drivers:
            # Create a folder for the driver if it doesn't exist
            driver_folder = f"{event}/{session}/{driver}"
            if not os.path.exists(driver_folder):
                os.makedirs(driver_folder)

            laptimes = laps_data(YEAR, event, session, driver)

            # Specify the file path where you want to save the JSON data
            file_path = f"{driver_folder}/laptimes.json"

            # Save the dictionary to a JSON file
            with open(file_path, "w") as json_file:
                json.dump(laptimes, json_file)

            # print(f"Dictionary saved to {file_path}")
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '4', '23', '11', '16', '55', '18', '3', '5', '10', '26', '31', '8', '20', '63', '99', '7', '6']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']
# core           INFO 	Loading data for Styrian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for Styrian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for Styrian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Styrian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Styrian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '55', '77', '31', '4', '23', '10', '3', '5', '16', '63', '18', '26', '20', '7', '11', '6', '99', '8']
# core           INFO 	Loading data for Styrian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '55', '77', '31', '4', '23', '10', '3', '5', '16', '63', '18', '26', '20', '7', '11', '6', '99', '8']
# core           INFO 	Loading data for Styrian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '4', '11', '18', '3', '55', '26', '7', '20', '8', '99', '10', '63', '6', '31', '16', '5']
# core           INFO 	Loading data for Styrian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '23', '4', '11', '18', '3', '55', '26', '7', '20', '8', '99', '10', '63', '6', '31', '16', '5']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 10
# core        WARNING 	No lap data for driver 7
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 10)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 7)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 10
# core        WARNING 	No lap data for driver 7
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 10)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 7)
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# core           INFO 	Loading data for Hungarian Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '18', '11', '5', '16', '33', '4', '55', '10', '3', '63', '23', '31', '6', '20', '26', '8', '99', '7']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '23', '5', '11', '3', '55', '20', '16', '26', '4', '31', '7', '8', '99', '63', '6', '10']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '23', '5', '11', '3', '55', '20', '16', '26', '4', '31', '7', '8', '99', '63', '6', '10']
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 0
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 65535
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 0)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 11)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 65535)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 23 drivers: ['0', '10', '11', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '65535', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 0
# core        WARNING 	No lap data for driver 11
# core        WARNING 	No lap data for driver 65535
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 0)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 11)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 65535)
# core           INFO 	Finished loading data for 23 drivers: ['0', '10', '11', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '65535', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# core           INFO 	Loading data for British Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '4', '18', '55', '3', '31', '5', '10', '23', '27', '26', '63', '20', '99', '7', '8', '6']
# core           INFO 	Loading data for British Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '3', '4', '31', '10', '23', '18', '5', '77', '63', '55', '99', '6', '8', '7', '26', '20', '27']
# core           INFO 	Loading data for British Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '3', '4', '31', '10', '23', '18', '5', '77', '63', '55', '99', '6', '8', '7', '26', '20', '27']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 21 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# core           INFO 	Finished loading data for 21 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '88', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '16', '18', '20', '23', '26', '27', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '27', '33', '3', '18', '10', '16', '23', '4', '31', '5', '55', '8', '63', '26', '20', '6', '99', '7']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '27', '33', '3', '18', '10', '16', '23', '4', '31', '5', '55', '8', '63', '26', '20', '6', '99', '7']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '23', '18', '27', '31', '4', '26', '10', '5', '55', '3', '7', '8', '99', '63', '6', '20']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '23', '18', '27', '31', '4', '26', '10', '5', '55', '3', '7', '8', '99', '63', '6', '20']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 63)
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '40', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '18', '23', '55', '4', '16', '10', '5', '26', '3', '7', '31', '20', '8', '63', '6', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '11', '18', '23', '55', '4', '16', '10', '5', '26', '3', '7', '31', '20', '8', '63', '6', '99']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '11', '55', '5', '23', '10', '4', '3', '26', '31', '7', '20', '99', '63', '6', '8', '16']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '11', '55', '5', '23', '10', '4', '3', '26', '31', '7', '20', '99', '63', '6', '8', '16']
# core           INFO 	Loading data for Belgian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Belgian Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Belgian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Belgian Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '55', '6', '63', '7', '77', '8', '99']
# core           INFO 	Loading data for Belgian Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# ...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '5', '51', '55', '6', '63', '7', '77', '89', '99']
# core           INFO 	Loading data for Sakhir Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['77', '63', '33', '16', '11', '26', '3', '55', '10', '18', '31', '23', '5', '99', '4', '20', '6', '89', '7', '51']
# core           INFO 	Loading data for Sakhir Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['77', '63', '33', '16', '11', '26', '3', '55', '10', '18', '31', '23', '5', '99', '4', '20', '6', '89', '7', '51']
# core           INFO 	Loading data for Sakhir Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['11', '31', '18', '55', '3', '23', '26', '77', '63', '4', '10', '5', '99', '7', '20', '89', '51', '6', '33', '16']
# core           INFO 	Loading data for Sakhir Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['11', '31', '18', '55', '3', '23', '26', '77', '63', '4', '10', '5', '99', '7', '20', '89', '51', '6', '33', '16']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 20
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 20)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '50', '51', '55', '6', '63', '7', '77', '88', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 1 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 20
# core        WARNING 	No lap data for driver 99
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 20)
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 99)
# core           INFO 	Finished loading data for 22 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '50', '51', '55', '6', '63', '7', '77', '88', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 2 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 3 [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '3', '31', '33', '4', '44', '5', '51', '55', '6', '63', '7', '77', '99']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Qualifying [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '4', '23', '55', '26', '18', '16', '10', '31', '3', '5', '99', '11', '7', '20', '63', '51', '6']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.1.6]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']

# %%
import concurrent.futures
import datetime
import functools
import math
import os
from io import BytesIO

import fastf1
import numpy as np
import pandas as pd
import requests
import streamlit as st
from fastapi import Depends, FastAPI
from fastapi.middleware.cors import CORSMiddleware
from fastapi.responses import FileResponse, HTMLResponse
from fastf1.ergast import Ergast
from pydantic import BaseModel, Field
from sqlalchemy.orm import Session

from . import accelerations, database, models, utils

# import accelerations
# import database
# import models
# import utils
FASTF1_CACHE_DIR = os.environ["FASTF1_CACHE_DIR"]

fastf1.Cache.enable_cache(FASTF1_CACHE_DIR)

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)


database.Base.metadata.create_all(bind=database.engine)


def get_db():
    try:
        db = database.SessionLocal()
        yield db
    finally:
        db.close()


class RacePace(BaseModel):
    year: int
    event: str
    session: str
    Driver: str
    LapTime: float
    Diff: float
    Team: str
    fill: str


# @functools.cache
@app.get("/racepace/{year}/{event}/{session}", response_model=None)
async def average_race_pace(
    year: int, event: str | int, session: str, db: Session = Depends(get_db)
) -> any:
    race_pace_data = (
        db.query(models.RacePace)
        .filter_by(year=year, event=event, session=session)
        .all()
    )

    if race_pace_data:
        print("Fetching from Database")

    if not race_pace_data:
        print("Writing to Database")
        f1session = fastf1.get_session(
            year,
            event,
            session,
            # backend="fastf1",
            # force_ergast=False,
        )
        f1session.load(telemetry=False, weather=False, messages=False)
        laps = f1session.laps

        laps = laps.loc[laps.LapNumber > 1]
        laps = laps.pick_track_status(
            "1",
        )
        laps["LapTime"] = laps.Sector1Time + laps.Sector2Time + laps.Sector3Time

        # convert LapTime to seconds
        laps["LapTime"] = laps["LapTime"].apply(lambda x: x.total_seconds())

        laps = laps.loc[laps.LapTime < laps.LapTime.min() * 1.07]

        df = (
            laps[["LapTime", "Driver"]].groupby("Driver").mean().reset_index(drop=False)
        )
        df = df.sort_values(by="LapTime").reset_index(drop=True)
        df["LapTime"] = df["LapTime"].round(3)
        df["Diff"] = (df["LapTime"] - df["LapTime"].min()).round(3)
        teams = laps[["Driver", "Team"]].drop_duplicates().reset_index(drop=True)
        # join teams and df
        df = df.merge(teams, on="Driver", how="left")

        car_colors = utils.team_colors(year)

        df["fill"] = df["Team"].map(car_colors)

        df_json = df.to_dict("records")

        # save the data to the database
        for record in df.to_dict("records"):
            race_pace = models.RacePace(**record)
            db.add(race_pace)

        db.commit()

        return {"racePace": df_json}

    return {"racePace": [dict(race_pace) for race_pace in race_pace_data]}


@functools.cache
@app.get("/topspeed/{year}/{event}/{session}", response_model=None)
async def top_speed(year: int, event: str | int, session: str) -> any:
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps
    team_colors = utils.team_colors(year)

    fastest_speedtrap = (
        laps[["SpeedI1", "SpeedI2", "SpeedST", "SpeedFL"]]
        .idxmax(axis=1)
        .value_counts()
        .index[0]
    )

    speed_df = (
        laps[[fastest_speedtrap, "Driver", "Compound", "Team"]]
        .groupby("Driver")
        .max()
        .sort_values(fastest_speedtrap, ascending=False)
        .reset_index()
    )
    # add team colors to dataframe
    speed_df["fill"] = speed_df["Team"].apply(lambda x: team_colors[x])

    # rename fastest speedtrap column to TopSpeed
    speed_df.rename(columns={fastest_speedtrap: "TopSpeed"}, inplace=True)

    # remove nan values in any column
    speed_df = speed_df.dropna()

    # Convert to int
    speed_df["TopSpeed"] = speed_df["TopSpeed"].astype(int)

    speed_dict = speed_df.to_dict(orient="records")

    return {"topSpeed": speed_dict}


@functools.cache
@app.get("/overtakes/{year}/{event}", response_model=None)
def get_overtakes(year: int, event: str) -> any:
    def get_overtakes_df(year, event):
        if year == 2023:
            url = "https://docs.google.com/spreadsheets/d/1M4aepPJaIfdqE9oU3L-2CQqKIyubLXG4Q4cqWnyqxp4/export?format=csv"
        if year == 2022:
            url = "https://docs.google.com/spreadsheets/d/1cuS3B6hk4iQmMaRQoMTcogIInJpavnV7rKuEsiJnEbU/export?format=csv"
        if year == 2021:
            url = "https://docs.google.com/spreadsheets/d/1ANQnPVkefRmvzrmGvEqXoqQ4dBfgcI_R9FPg-0BcM34/export?format=csv"
        if year == 2020:
            url = "https://docs.google.com/spreadsheets/d/1eG9WTkXKzFT4NMh-WqHOMs5G0UuPGnb6wP4CnFD8uzY/export?format=csv"
        if year == 2019:
            url = "https://docs.google.com/spreadsheets/d/10nHg7BIs5ySh_dE9uuIz2lq-gRWcg02tIMr0EPgPvJs/export?format=csv"
        if year == 2018:
            url = "https://docs.google.com/spreadsheets/d/1MyAwQdczccdca_FAIiZKkqZNauNh3ts99JZ278S2OKc/export?format=csv"

        response = requests.get(url, timeout=10)
        df = pd.read_csv(BytesIO(response.content))
        df = df[["Driver", event]]
        # replace NaNs with 0s
        df = df.fillna(0)
        # convert numbers to ints
        df[event] = df[event].astype(int)
        # replace event with "overtakes"
        df = df.rename(columns={event: "overtakes"})
        return df

    def get_overtaken_df(year, event):
        if year == 2023:
            url = "https://docs.google.com/spreadsheets/d/1wszzx694Ot-mvA5YrFCpy3or37xMgnC0XpE8uNnJLWk/export?format=csv"
        if year == 2022:
            url = "https://docs.google.com/spreadsheets/d/19_XFDD3BZDIQVkNE4bG6dwuKvMaO4g5HNaUARGaJwhE/export?format=csv"
        if year == 2021:
            url = "https://docs.google.com/spreadsheets/d/1dQBHnd3AXEPNH5I75cjbzAAzi9ipqGk3v9eZT9eYKS4/export?format=csv"
        if year == 2020:
            url = "https://docs.google.com/spreadsheets/d/1snyntPMxYH4_KHSRI96AwBoJQrPbX6OanJAcqbYyW-Y/export?format=csv"
        if year == 2019:
            url = "https://docs.google.com/spreadsheets/d/11FfFkXErJg7F22iVwJo9XfLFAWucMBVlzL1qUGWxM3s/export?format=csv"
        if year == 2018:
            url = "https://docs.google.com/spreadsheets/d/1XJXAEyRpRS_UwLHzEtN2PdIaFJYGWSN6ypYN8Ecwp9A/export?format=csv"

        response = requests.get(url, timeout=10)
        df = pd.read_csv(BytesIO(response.content))
        df = df[["Driver", event]]
        # replace NaNs with 0s
        df = df.fillna(0)
        # convert numbers to ints
        df[event] = df[event].astype(int)
        df = df.rename(columns={event: "overtaken"})
        return df

    overtakes = get_overtakes_df(year, event)
    overtaken = get_overtaken_df(year, event)
    df = overtakes.merge(overtaken, on="Driver")

    # remove drivers with 0 overtakes and 0 overtaken
    df = df[(df["overtakes"] != 0) | (df["overtaken"] != 0)]

    # sort in the decreasing order of overtakes
    df = df.sort_values(
        by=["overtakes", "overtaken"], ascending=[False, True]
    ).reset_index(drop=True)
    # convert to dictionary
    df_dict = df.to_dict(orient="records")

    return {"overtakes": df_dict}


@functools.cache
@app.get("/fastest/{year}/{event}/{session}", response_model=None)
async def fastest_lap(year: int, event: str | int, session: str) -> any:
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps

    drivers = pd.unique(laps["Driver"])

    list_fastest_laps = list()

    for drv in drivers:
        drvs_fastest_lap = laps.pick_driver(drv).pick_fastest()
        list_fastest_laps.append(drvs_fastest_lap)

    df = (
        fastf1.core.Laps(list_fastest_laps)
        .sort_values(by="LapTime")
        .reset_index(drop=True)
    )

    pole_lap = df.pick_fastest()
    df["Diff"] = df["LapTime"] - pole_lap["LapTime"]

    car_colors = utils.team_colors(year)

    df["fill"] = df["Team"].map(car_colors)

    # convert timedelta to float and round to 3 decimal places
    df["Diff"] = df["Diff"].dt.total_seconds().round(3)
    df = df[["Driver", "LapTime", "Diff", "Team", "fill"]]

    # remove nan values in any column
    df = df.dropna()

    df_json = df.to_dict("records")

    return {"fastest": df_json}


# @st.cache_data


@app.get("/wdc", response_model=None)
async def driver_standings() -> any:
    YEAR = 2023  # datetime.datetime.now().year
    df = pd.DataFrame(
        pd.read_html(f"https://www.formula1.com/en/results.html/{YEAR}/drivers.html")[0]
    )
    df = df[["Driver", "PTS", "Car"]]
    # reverse the order
    df = df.sort_values(by="PTS", ascending=True)

    # in Driver column only keep the last 3 characters
    df["Driver"] = df["Driver"].str[:-5]

    # add colors to the dataframe
    car_colors = utils.team_colors(YEAR)
    df["fill"] = df["Car"].map(car_colors)

    # remove rows where points is 0
    df = df[df["PTS"] != 0]
    df.reset_index(inplace=True, drop=True)
    df.rename(columns={"PTS": "Points"}, inplace=True)

    return {"WDC": df.to_dict("records")}


# @st.cache_data


@app.get("/", response_model=None)
async def root():
    return HTMLResponse(
        content="""<iframe src="https://tracinginsights-f1-analysis.hf.space" frameborder="0" style="width:100%; height:100%;" scrolling="yes" allowfullscreen:"yes"></iframe>""",
        status_code=200,
    )


# @st.cache_data


@app.get("/years", response_model=None)
async def years_available() -> any:
    # make a list from 2018 to current year
    current_year = datetime.datetime.now().year
    years = list(range(2018, current_year + 1))
    # reverse the list to get the latest year first
    years.reverse()
    years = [{"label": str(year), "value": year} for year in years]
    return {"years": years}


# format for events {"events":[{"label":"Saudi Arabian Grand Prix","value":2},{"label":"Bahrain Grand Prix","value":1},{"label":"Pre-Season Testing","value":"t1"}]}

# @st.cache_data


@app.get("/{year}", response_model=None)
async def events_available(year: int) -> any:
    # get events available for a given year
    data = utils.LatestData(year)
    events = data.get_events()
    events = [{"label": event, "value": event} for i, event in enumerate(events)]
    events.reverse()

    return {"events": events}


# format for sessions {"sessions":[{"label":"FP1","value":"FP1"},{"label":"FP2","value":"FP2"},{"label":"FP3","value":"FP3"},{"label":"Qualifying","value":"Q"},{"label":"Race","value":"R"}]}


# @st.cache_data
@functools.cache
@app.get("/{year}/{event}", response_model=None)
async def sessions_available(year: int, event: str | int) -> any:
    # get sessions available for a given year and event
    data = utils.LatestData(year)
    sessions = data.get_sessions(event)
    sessions = [{"label": session, "value": session} for session in sessions]

    return {"sessions": sessions}


# format for drivers {"drivers":[{"color":"#fff500","label":"RIC","value":"RIC"},{"color":"#ff8700","label":"NOR","value":"NOR"},{"color":"#c00000","label":"VET","value":"VET"},{"color":"#0082fa","label":"LAT","value":"LAT"},{"color":"#787878","label":"GRO","value":"GRO"},{"color":"#ffffff","label":"GAS","value":"GAS"},{"color":"#f596c8","label":"STR","value":"STR"},{"color":"#787878","label":"MAG","value":"MAG"},{"color":"#0600ef","label":"ALB","value":"ALB"},{"color":"#ffffff","label":"KVY","value":"KVY"},{"color":"#fff500","label":"OCO","value":"OCO"},{"color":"#0600ef","label":"VER","value":"VER"},{"color":"#00d2be","label":"HAM","value":"HAM"},{"color":"#ff8700","label":"SAI","value":"SAI"},{"color":"#00d2be","label":"BOT","value":"BOT"},{"color":"#960000","label":"GIO","value":"GIO"}]}

# @st.cache_data


@functools.cache
@app.get("/strategy/{year}/{event}", response_model=None)
async def get_strategy(year: int, event: str | int) -> any:
    f1session = fastf1.get_session(year, event, "R")
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps

    drivers_list = pd.unique(laps["Driver"])

    drivers = pd.DataFrame(drivers_list, columns=["Driver"])
    drivers["FinishOrder"] = drivers.index + 1

    # Get the LapNumber of the first lap of each stint
    first_lap = (
        laps[["Driver", "Stint", "Compound", "LapNumber"]]
        .groupby(["Driver", "Stint", "Compound"])
        .first()
        .reset_index()
    )
    #  Add FinishOrder to first_lap
    first_lap = pd.merge(first_lap, drivers, on="Driver")
    # change LapNumber to LapStart
    first_lap = first_lap.rename(columns={"LapNumber": "LapStart"})
    # reduce the lapstart by 1
    first_lap["LapStart"] = first_lap["LapStart"] - 1

    # find the last lap of each stint
    last_lap = (
        laps[["Driver", "Stint", "Compound", "LapNumber"]]
        .groupby(["Driver", "Stint", "Compound"])
        .last()
        .reset_index()
    )
    #  change LapNumber to LapEnd
    last_lap = last_lap.rename(columns={"LapNumber": "LapEnd"})

    # combine first_lap and last_lap
    stint_laps = pd.merge(first_lap, last_lap, on=["Driver", "Stint", "Compound"])
    #  to cover for outliers
    stint_laps["fill"] = "white"

    stint_laps["fill"] = stint_laps["Compound"].map(
        {
            "SOFT": "red",
            "MEDIUM": "yellow",
            "HARD": "white",
            "INTERMEDIATE": "blue",
            "WET": "green",
        }
    )

    # sort by FinishOrder
    stint_laps = stint_laps.sort_values(by=["FinishOrder"], ascending=[True])

    stint_laps_dict = stint_laps.to_dict("records")

    return {"strategy": stint_laps_dict}

# lap position
@functools.cache
@app.get("/lapchart/{year}/{event}/{session}", response_model=None)
async def lap_chart(
    year: int,
    event: str | int,
    session: str,
) -> any:
    ergast = Ergast()

    race_names_df = ergast.get_race_schedule(season=year, result_type="pandas")
    event_number = race_names_df[race_names_df["raceName"] == event]["round"].values[0]
    drivers_df = ergast.get_driver_info(
        season=year, round=event_number, result_type="pandas"
    )
    laptimes_df = ergast.get_lap_times(
        season=year, round=event_number, result_type="pandas", limit=2000
    ).content[0]
    laptimes_df = pd.merge(laptimes_df, drivers_df, how="left", on="driverId")

    results_df = ergast.get_race_results(
        season=year, round=event_number, result_type="pandas"
    ).content[0]
    results_df = results_df[["driverCode", "constructorName"]]

    # merge results_df on laptime_df
    laptimes_df = pd.merge(laptimes_df, results_df, how="left", on="driverCode")

    team_colors = utils.team_colors(year)
    # add team_colors to laptimes_df
    laptimes_df["fill"] = laptimes_df["constructorName"].map(team_colors)

    #  rename number as x and position as y
    laptimes_df.rename(
        columns={"number": "x", "position": "y", "driverCode": "id"}, inplace=True
    )

    lap_chart_data = []

    for driver in laptimes_df["id"].unique():
        data = laptimes_df[laptimes_df["id"] == driver]
        fill = data["fill"].values[0]
        data = data[["x", "y"]]
        data_dict = data.to_dict(orient="records")
        driver_dict = {"id": driver, "fill": fill, "data": data_dict}
        # add this to all_data
        lap_chart_data.append(driver_dict)

    lap_chart_dict = {"lapChartData": lap_chart_data}

    return lap_chart_dict


@functools.cache
@app.get("/{year}/{event}/{session}", response_model=None)
async def session_drivers(year: int, event: str | int, session: str) -> any:
    # get drivers available for a given year, event and session
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)

    laps = f1session.laps
    team_colors = utils.team_colors(year)
    # add team_colors dict to laps on Team column
    laps["color"] = laps["Team"].map(team_colors)

    unique_drivers = laps["Driver"].unique()

    drivers = [
        {
            "color": laps[laps.Driver == driver].color.iloc[0],
            "label": driver,
            "value": driver,
        }
        for driver in unique_drivers
    ]

    return {"drivers": drivers}

# select laps similar to select drivers select box
@functools.cache
@app.get("/laps/{year}/{event}/{session}", response_model=None)
async def get_driver_laps_data(year: int, event: str | int, session: str) -> any:
    # get drivers available for a given year, event and session
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps
    team_colors = utils.team_colors(year)
    # add team_colors dict to laps on Team column
    laps["color"] = laps["Team"].map(team_colors)

    # combine Driver and LapNumber as a new column
    laps["label"] = (
        laps["Driver"]
        + "-"
        + laps["LapNumber"].astype(int).astype(str)
        + "-"
        + str(year)
        + "-"
        + event
        + "-"
        + session
    )
    laps["value"] = (
        laps["Driver"]
        + "-"
        + laps["LapNumber"].astype(int).astype(str)
        + "-"
        + str(year)
        + "-"
        + event
        + "-"
        + session
    )

    laps = laps[["value", "label", "color"]]

    driver_laps_dict = laps.to_dict("records")

    return {"laps": driver_laps_dict}


# format for chartData {"chartData":[{"lapnumber":1},{
# "VER":91.564,
# "VER_compound":"SOFT",
# "VER_compound_color":"#FF5733",
# "lapnumber":2
# },{"lapnumber":3},{"VER":90.494,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":4},{"lapnumber":5},{"VER":90.062,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":6},{"lapnumber":7},{"VER":89.815,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":8},{"VER":105.248,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":9},{"lapnumber":10},{"VER":89.79,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":11},{"VER":145.101,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":12},{"lapnumber":13},{"VER":89.662,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":14},{"lapnumber":15},{"VER":89.617,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":16},{"lapnumber":17},{"VER":140.717,"VER_compound":"SOFT","VER_compound_color":"#FF5733","lapnumber":18}]}

# @st.cache_data


@functools.cache
@app.get("/{year}/{event}/{session}/{driver}", response_model=None)
async def laps_data(year: int, event: str | int, session: str, driver: str) -> any:
    # get drivers available for a given year, event and session
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps
    team_colors = utils.team_colors(year)
    # add team_colors dict to laps on Team column

    drivers = laps.Driver.unique()
    # for each driver in drivers, get the Team column from laps and get the color from team_colors dict
    drivers = [
        {
            "color": team_colors[laps[laps.Driver == driver].Team.iloc[0]],
            "label": driver,
            "value": driver,
        }
        for driver in drivers
    ]

    driver_laps = laps.pick_driver(driver)
    driver_laps["LapTime"] = driver_laps["LapTime"].dt.total_seconds()
    # remove rows where LapTime is null
    driver_laps = driver_laps[driver_laps.LapTime.notnull()]
    compound_colors = {
        "SOFT": "#FF0000",
        "MEDIUM": "#FFFF00",
        "HARD": "#FFFFFF",
        "INTERMEDIATE": "#00FF00",
        "WET": "#088cd0",
    }

    driver_laps_data = []

    for _, row in driver_laps.iterrows():
        if row["LapTime"] > 0:
            lap = {
                f"{driver}": row["LapTime"],
                f"{driver}_compound": row["Compound"],
                f"{driver}_compound_color": compound_colors[row["Compound"]],
                "lapnumber": row["LapNumber"],
            }
        else:
            lap = {"lapnumber": row["LapNumber"]}

        driver_laps_data.append(lap)

    return {"chartData": driver_laps_data}


@functools.cache
@app.get("/laptimes/{year}/{event}/{session}/{driver}", response_model=None)
async def get_laps_data(year: int, event: str | int, session: str, driver: str) -> any:
    # get drivers available for a given year, event and session
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=False, weather=False, messages=False)
    laps = f1session.laps
    team_colors = utils.team_colors(year)
    # add team_colors dict to laps on Team column

    drivers = laps.Driver.unique()
    # for each driver in drivers, get the Team column from laps and get the color from team_colors dict
    drivers = [
        {
            "color": team_colors[laps[laps.Driver == driver].Team.iloc[0]],
            "label": driver,
            "value": driver,
        }
        for driver in drivers
    ]

    driver_laps = laps.pick_driver(driver)
    driver_laps["LapTime"] = driver_laps["LapTime"].dt.total_seconds()
    driver_laps = driver_laps[["Driver", "LapTime", "LapNumber", "Compound"]]

    # remove rows where LapTime is null
    driver_laps = driver_laps[driver_laps.LapTime.notnull()]

    driver_laps_dict = driver_laps.to_dict("records")

    return {"chartData": driver_laps_dict}


# @st.cache_data


@functools.cache
@app.get("/{year}/{event}/{session}/{driver}/{lap_number}", response_model=None)
async def telemetry_data(
    year: int, event: str | int, session: str, driver: str, lap_number: int
) -> any:
    f1session = fastf1.get_session(year, event, session)
    f1session.load(telemetry=True, weather=False, messages=False)
    laps = f1session.laps

    driver_laps = laps.pick_driver(driver)
    driver_laps["LapTime"] = driver_laps["LapTime"].dt.total_seconds()

    # get the telemetry for lap_number
    selected_lap = driver_laps[driver_laps.LapNumber == lap_number]

    telemetry = selected_lap.get_telemetry()

    lon_acc, lat_acc = accelerations.compute_accelerations(telemetry)
    telemetry["lon_acc"] = lon_acc
    telemetry["lat_acc"] = lat_acc

    telemetry["Time"] = telemetry["Time"].dt.total_seconds()

    laptime = selected_lap.LapTime.values[0]
    data_key = f"{driver} - Lap {int(lap_number)} - {year} {session} [laptime]"

    telemetry["DRS"] = telemetry["DRS"].apply(lambda x: 1 if x in [10, 12, 14] else 0)

    brake_tel = []
    drs_tel = []
    gear_tel = []
    rpm_tel = []
    speed_tel = []
    throttle_tel = []
    time_tel = []
    track_map = []
    lon_acc_tel = []
    lat_acc_tel = []

    for _, row in telemetry.iterrows():
        brake = {
            "x": row["Distance"],
            "y": row["Brake"],
        }
        brake_tel.append(brake)

        drs = {
            "x": row["Distance"],
            "y": row["DRS"],
        }
        drs_tel.append(drs)

        gear = {
            "x": row["Distance"],
            "y": row["nGear"],
        }
        gear_tel.append(gear)

        rpm = {
            "x": row["Distance"],
            "y": row["RPM"],
        }
        rpm_tel.append(rpm)

        speed = {
            "x": row["Distance"],
            "y": row["Speed"],
        }
        speed_tel.append(speed)

        throttle = {
            "x": row["Distance"],
            "y": row["Throttle"],
        }
        throttle_tel.append(throttle)

        time = {
            "x": row["Distance"],
            "y": row["Time"],
        }
        time_tel.append(time)

        lon_acc = {
            "x": row["Distance"],
            "y": row["lon_acc"],
        }
        lon_acc_tel.append(lon_acc)

        lat_acc = {
            "x": row["Distance"],
            "y": row["lat_acc"],
        }
        lat_acc_tel.append(lat_acc)

        track = {
            "x": row["X"],
            "y": row["Y"],
        }
        track_map.append(track)

    telemetry_data = {
        "telemetryData": {
            "brake": brake_tel,
            "dataKey": data_key,
            "drs": drs_tel,
            "gear": gear_tel,
            "rpm": rpm_tel,
            "speed": speed_tel,
            "throttle": throttle_tel,
            "time": time_tel,
            "lon_acc": lon_acc_tel,
            "lat_acc": lat_acc_tel,
            "trackMap": track_map,
        }
    }

    return telemetry_data
